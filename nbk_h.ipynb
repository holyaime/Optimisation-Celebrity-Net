# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import albumentations as A
from celebrity_recognition_ai.ml.data import get_train_and_validation_images_path, CelebrityDataset
from celebrity_recognition_ai.ml.models import CelebrityNet
import torch.optim as optim
from celebrity_recognition_ai.ml.engine import one_epoch_training

# %%
base_path = "/home/holy/Documents/Data"



(categories,
 train_images_absolute_paths, 
 validation_images_absolute_paths) = get_train_and_validation_images_path(base_path, percentage_train=0.8)

# %%
len(validation_images_absolute_paths)
#categories
# Out:
# 240

# %%
train_dataset = CelebrityDataset(train_images_absolute_paths, categories)

len(train_dataset)
# Out:
# 960

# %%
params = {'batch_size': 64,
          'shuffle': True,
          'num_workers': 6}

# %%
training_generator = torch.utils.data.DataLoader(train_dataset, **params)

# %%
model = CelebrityNet(num_classes=len(categories))

# %%
X = train_dataset[0][0].unsqueeze(0)
model(X)
# Out:
# tensor([[ 0.0582,  0.0420, -0.0858,  0.0017,  0.1319, -0.1011]],
#        grad_fn=<AddmmBackward0>)

# %%
    # Évaluer le modèle sur l'ensemble de validation
    
total_val_loss = 0.0
correct_predictions = 0
total_samples = 0
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# CelebrityNet(
#   (backbone): EfficientNet(
#     (conv_stem): Conv2d(3, 48, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (bn1): BatchNormAct2d(
#       48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#       (drop): Identity()
#       (act): SiLU(inplace=True)
#     )
#     (blocks): Sequential(
#       (0): Sequential(
#         (0): DepthwiseSeparableConv(
#           (conv_dw): Conv2d(48, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=48, bias=False)
#           (bn1): BatchNormAct2d(
#             48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True
#             (drop): Identity()
#             (act): SiLU(inplace=True)
#           )
#           (se): SqueezeExcite(
#             (conv_reduce): Conv2d(48, 12, kernel_size=(1, 1), stride=(1, 1))
#             (act1): SiLU(inplace=True)
#             (conv_expand): Conv2d(12, 48, kernel_size=(1, 1), stride=(1, 1))
#             (gate): Sigmoid()
#           )
# ...

# %%
one_epoch_training(training_generator, model, criterion, optimizer, device, breakpoint=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 one_epoch_training(training_generator, model, criterion, optimizer, device, breakpoint=20)
#
# File ~/mes_projets/Celebrity/celebrity-recognition-ai/celebrity_recognition_ai/ml/engine.py:15, in one_epoch_training(dataloader, model, criterion, optimizer, device, breakpoint)
#      13 correct_predictions = 0
#      14 total_samples = 0
# ---> 15 for i, batch in enumerate(dataloader):
#      16     if i == breakpoint:
#      17         break
#
# File ~/.cache/pypoetry/virtualenvs/celebrity-recognition-ai-3SwpldQB-py3.10/lib/python3.10/site-packages/torch/utils/data/dataloader.py:631, in _BaseDataLoaderIter.__next__(self)
#     628 if self._sampler_iter is None:
#     629     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     630     self._reset()  # type: ignore[call-arg]
# ...
